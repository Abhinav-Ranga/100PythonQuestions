# %%
def divchecker(n1):
    if n1%6 ==0:
        print('this is a divisible of 3 and 6')
    else:
        print('this is not divisible by 3 and 6')





n1 = int(input('Enter the number: '))
divchecker(n1)
# Out:
# Enter the number:  23432
# this is not divisible by 3 and 6
